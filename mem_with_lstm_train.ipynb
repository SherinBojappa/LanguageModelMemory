# %%
# %matplotlib inline
# Out:
# Loaded backend module://matplotlib_inline.backend_inline version unknown.

# %%
import logging
 
logging.basicConfig(filename = 'mem_with_lstm_train.log',
                    level = logging.DEBUG,
                    format = '%(asctime)s:%(levelname)s:%(name)s:%(message)s')
logging.getLogger().addHandler(logging.StreamHandler())

# %%
from tqdm import tqdm
import numpy as np
import pandas as pd

# %%
import torch
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.utils.data import random_split

# %%
import torchmetrics
# Out:
# Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# Creating converter from 7 to 5
# Creating converter from 7 to 5
# Creating converter from 5 to 7
# Creating converter from 5 to 7
# Creating converter from 7 to 5
# Creating converter from 7 to 5
# Creating converter from 5 to 7
# Creating converter from 5 to 7

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
train_context_reps = torch.load('train_context_lstm_reps.pt')

# %%
len(train_context_reps)
# Out:
# 70749

# %%
train_context_reps = torch.load('train_context_lstm_reps.pt')
val_context_reps = torch.load('val_context_lstm_reps.pt')
test_context_reps = torch.load('test_context_lstm_reps.pt')

# %%
train_query_reps = torch.load('train_query_lstm_reps.pt')
val_query_reps = torch.load('val_query_lstm_reps.pt')
test_query_reps = torch.load('test_query_lstm_reps.pt')

# %%
train_label = torch.load('train_label.pt')
val_label = torch.load('val_label.pt')
test_label = torch.load('test_label.pt')

# %%
def get_data_loader(context_reps, query_reps, label, batch_size, shuffle):
    data_set = TensorDataset(context_reps, query_reps, label)
    loader = DataLoader(data_set, batch_size=batch_size, shuffle=shuffle)
    return loader

# %%
batch_size = 128

# %%
train_loader = get_data_loader(train_context_reps, train_query_reps, train_label, batch_size, shuffle=True)
val_loader = get_data_loader(val_context_reps, val_query_reps, val_label, batch_size, shuffle=False)
test_loader = get_data_loader(test_context_reps, test_query_reps, test_label, batch_size, shuffle=False)

# %%
class MemNetwork(nn.Module):
    def __init__(self):
        super(MemNetwork, self).__init__()
        
        self.linear = nn.Sequential(
            nn.Linear(400, 400)
        )

    def forward(self, x, y):

        x_input = self.linear(x)
        op = torch.sum(x_input*y, dim=1)
        return op

# %%
model = MemNetwork().to(device)
print(model)
# Out:
# MemNetwork(
#   (linear): Sequential(
#     (0): Linear(in_features=400, out_features=400, bias=True)
#   )
# )

# %%
num_epochs = 50
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.01, weight_decay=0.0001)
scheduler = StepLR(optimizer, step_size=5, gamma=0.8)

# %%
checkpoint_path = '/data/sherin/checkpoint_lm/chkpt_lm_lstm_wdcy_steplr_recall_best.pt.tar'

# %%
epoch_loss_list = []
accuracy_list = []
val_loss_list = []
val_acc_list = []
valid_acc_max = 0 

for epoch in range(num_epochs):
    train_count = 0
    model.train()
    epoch_loss = 0.0
    accuracy = 0.0
    

    for context, query, labels in tqdm(train_loader):
        train_count = train_count+1
        context = context.to(device)
        query = query.to(device)    
        target = labels.to(device)
        label = labels.float().to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(context, query)
        loss = criterion(outputs, label)
        loss.backward()

        optimizer.step()
        
        epoch_loss += loss.item()
        accuracy += torchmetrics.functional.accuracy(outputs, target, threshold=0.5).item()

    
    model.eval()
    val_loss = 0.0
    val_acc = 0.0
    
    test_count = 0
    for context, query, labels in tqdm(val_loader):
        test_count = test_count + 1
        context = context.to(device)
        query = query.to(device)
        target = labels.to(device)
        label = labels.float().to(device)
        
        outputs = model(context, query)
        loss = criterion(outputs, label)
        val_loss += loss.item()
        val_acc += torchmetrics.functional.accuracy(outputs, target, threshold=0.5).item()
        
    accuracy = accuracy / train_count
    epoch_loss = epoch_loss / train_count
    val_loss = val_loss / test_count
    val_acc = val_acc / test_count
    
    if val_acc > valid_acc_max:
        logging.info("saving best model")
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': val_loss,
            'accuracy': val_acc,
            }, checkpoint_path)
        valid_acc_max = val_acc
    else:
        logging.info("not saving the model")
    
    curr_lr = optimizer.param_groups[0]['lr']
    logging.info(f'curr_lr: {curr_lr}')
    logging.info(f'[{epoch + 1}] Training loss: {epoch_loss:.3f} Training accuracy : {accuracy:.3f}')
    logging.info(f'[{epoch + 1}] Validation loss: {val_loss:.3f} Validation accuracy : {val_acc:.3f}')
    epoch_loss_list.append(epoch_loss)
    accuracy_list.append(accuracy)
    val_loss_list.append(val_loss)
    val_acc_list.append(val_acc)
    
    scheduler.step()

print('Finished Training')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:02<00:00, 203.40it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 341.18it/s]
# saving best model
# saving best model
# curr_lr: 0.01
# curr_lr: 0.01
# [1] Training loss: 1.426 Training accuracy : 0.636
# [1] Training loss: 1.426 Training accuracy : 0.636
# [1] Validation loss: 1.856 Validation accuracy : 0.586
# [1] Validation loss: 1.856 Validation accuracy : 0.586
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:02<00:00, 261.54it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 337.21it/s]
# saving best model
# saving best model
# curr_lr: 0.01
# curr_lr: 0.01
# [2] Training loss: 1.064 Training accuracy : 0.715
# [2] Training loss: 1.064 Training accuracy : 0.715
# [2] Validation loss: 2.358 Validation accuracy : 0.590
# [2] Validation loss: 2.358 Validation accuracy : 0.590
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:01<00:00, 277.02it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 347.36it/s]
# saving best model
# saving best model
# curr_lr: 0.01
# curr_lr: 0.01
# [3] Training loss: 0.959 Training accuracy : 0.741
# [3] Training loss: 0.959 Training accuracy : 0.741
# [3] Validation loss: 2.183 Validation accuracy : 0.595
# [3] Validation loss: 2.183 Validation accuracy : 0.595
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:01<00:00, 276.85it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 351.84it/s]
# not saving the model
# not saving the model
# curr_lr: 0.01
# curr_lr: 0.01
# [4] Training loss: 0.926 Training accuracy : 0.751
# [4] Training loss: 0.926 Training accuracy : 0.751
# [4] Validation loss: 2.010 Validation accuracy : 0.592
# [4] Validation loss: 2.010 Validation accuracy : 0.592
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:01<00:00, 278.15it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 347.49it/s]
# not saving the model
# not saving the model
# curr_lr: 0.01
# curr_lr: 0.01
# [5] Training loss: 0.885 Training accuracy : 0.761
# [5] Training loss: 0.885 Training accuracy : 0.761
# [5] Validation loss: 1.999 Validation accuracy : 0.591
# [5] Validation loss: 1.999 Validation accuracy : 0.591
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:02<00:00, 265.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 350.23it/s]
# not saving the model
# not saving the model
# curr_lr: 0.008
# curr_lr: 0.008
# [6] Training loss: 0.692 Training accuracy : 0.787
# [6] Training loss: 0.692 Training accuracy : 0.787
# [6] Validation loss: 1.801 Validation accuracy : 0.595
# [6] Validation loss: 1.801 Validation accuracy : 0.595
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:01<00:00, 279.25it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00,
/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 347.22it/s]
# not saving the model
# not saving the model
# curr_lr: 0.00512
# curr_lr: 0.00512
# [17] Training loss: 0.426 Training accuracy : 0.832
# [17] Training loss: 0.426 Training accuracy : 0.832
# [17] Validation loss: 1.525 Validation accuracy : 0.591
# [17] Validation loss: 1.525 Validation accuracy : 0.591
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:02<00:00, 262.63it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 340.83it/s]
# not saving the model
# not saving the model
# curr_lr: 0.00512
# curr_lr: 0.00512
# [18] Training loss: 0.449 Training accuracy : 0.823
# [18] Training loss: 0.449 Training accuracy : 0.823
# [18] Validation loss: 1.547 Validation accuracy : 0.589
# [18] Validation loss: 1.547 Validation accuracy : 0.589
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:01<00:00, 279.93it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 352.86it/s]
# not saving the model
# not saving the model
# curr_lr: 0.00512
# curr_lr: 0.00512
# [19] Training loss: 0.452 Training accuracy : 0.822
# [19] Training loss: 0.452 Training accuracy : 0.822
# [19] Validation loss: 1.768 Validation accuracy : 0.584
# [19] Validation loss: 1.768 Validation accuracy : 0.584
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:02<00:00, 276.20it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 341.55it/s]
# saving best model
# saving best model
# curr_lr: 0.00512
# curr_lr: 0.00512
# [20] Training loss: 0.445 Training accuracy : 0.824
# [20] Training loss: 0.445 Training accuracy : 0.824
# [20] Validation loss: 1.377 Validation accuracy : 0.602
# [20] Validation loss: 1.377 Validation accuracy : 0.602
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:02<00:00, 264.05it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 347.44it/s]
# not saving the model
# not saving the model
# curr_lr: 0.004096000000000001
# curr_lr: 0.004096000000000001
# [21] Training loss: 0.362 Training accuracy : 0.848
# [21] Training loss: 0.362 Training accuracy : 0.848
# [21] Validation loss: 1.393 Validation accuracy : 0.593
# [21] Validation loss: 1.393 Validation accuracy : 0.593
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:01<00:00, 278.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 351.34it/s]
# not saving the model
# not saving the model
# curr_lr: 0.004096000000000001
# curr_lr: 0.004096000000000001
# [22] Training loss: 0.363 Training accuracy : 0.847
# [22] Training loss: 0.363 Training accuracy : 0.847
# [22] Validation loss: 1.343 Validation accuracy : 0.600
# [22] Validation loss: 1.343 Validation accuracy : 0.600
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:02<00:00, 275.75it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 353.42it/s]
# not saving the model
# not saving the model
# curr_lr: 0.004096000000000001
# curr_lr: 0.004096000000000001
# [23] Training loss: 0.379 Training accuracy : 0.841
# [23] Training loss: 0.379 Training accuracy : 0.841
# [23] Validation loss: 1.547 Validation accuracy : 0.587
# [23] Validation loss: 1.547 Validation accuracy : 0.587
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:01<00:00, 278.83it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 357.71it/s]
# not saving the model
# not saving the model
# curr_lr: 0.004096000000000001
# curr_lr: 0.004096000000000001
# [24] Training loss: 0.386 Training accuracy : 0.838
# [24] Training loss: 0.386 Training accuracy : 0.838
# [24] Validation loss: 1.430 Validation accuracy : 0.592
# [24] Validation loss: 1.430 Validation accuracy : 0.592
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:02<00:00, 269.68it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 343.46it/s]
# not saving the model
# not saving the model
# curr_lr: 0.004096000000000001
# curr_lr: 0.004096000000000001
# [25] Training loss: 0.379 Training accuracy : 0.841
# [25] Training loss: 0.379 Training accuracy : 0.841
# [25] Validation loss: 1.295 Validation accuracy : 0.594
# [25] Validation loss: 1.295 Validation accuracy : 0.594
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:02<00:00, 259.59it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 340.77it/s]
# not saving the model
# not saving the model
# curr_lr: 0.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:02<00:00, 273.48it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 348.44it/s]
# not saving the model
# not saving the model
# curr_lr: 0.002097152000000001
# curr_lr: 0.002097152000000001
# [37] Training loss: 0.261 Training accuracy : 0.887
# [37] Training loss: 0.261 Training accuracy : 0.887
# [37] Validation loss: 1.214 Validation accuracy : 0.590
# [37] Validation loss: 1.214 Validation accuracy : 0.590
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:01<00:00, 291.64it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 352.16it/s]
# not saving the model
# not saving the model
# curr_lr: 0.002097152000000001
# curr_lr: 0.002097152000000001
# [38] Training loss: 0.263 Training accuracy : 0.885
# [38] Training loss: 0.263 Training accuracy : 0.885
# [38] Validation loss: 1.175 Validation accuracy : 0.599
# [38] Validation loss: 1.175 Validation accuracy : 0.599
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:01<00:00, 283.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 376.72it/s]
# not saving the model
# not saving the model
# curr_lr: 0.002097152000000001
# curr_lr: 0.002097152000000001
# [39] Training loss: 0.268 Training accuracy : 0.882
# [39] Training loss: 0.268 Training accuracy : 0.882
# [39] Validation loss: 1.176 Validation accuracy : 0.593
# [39] Validation loss: 1.176 Validation accuracy : 0.593
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:01<00:00, 289.31it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 350.83it/s]
# not saving the model
# not saving the model
# curr_lr: 0.002097152000000001
# curr_lr: 0.002097152000000001
# [40] Training loss: 0.270 Training accuracy : 0.881
# [40] Training loss: 0.270 Training accuracy : 0.881
# [40] Validation loss: 1.165 Validation accuracy : 0.596
# [40] Validation loss: 1.165 Validation accuracy : 0.596
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:01<00:00, 285.57it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 379.21it/s]
# not saving the model
# not saving the model
# curr_lr: 0.001677721600000001
# curr_lr: 0.001677721600000001
# [41] Training loss: 0.244 Training accuracy : 0.896
# [41] Training loss: 0.244 Training accuracy : 0.896
# [41] Validation loss: 1.166 Validation accuracy : 0.595
# [41] Validation loss: 1.166 Validation accuracy : 0.595
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:01<00:00, 280.99it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 365.31it/s]
# not saving the model
# not saving the model
# curr_lr: 0.001677721600000001
# curr_lr: 0.001677721600000001
# [42] Training loss: 0.245 Training accuracy : 0.897
# [42] Training loss: 0.245 Training accuracy : 0.897
# [42] Validation loss: 1.131 Validation accuracy : 0.601
# [42] Validation loss: 1.131 Validation accuracy : 0.601
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:01<00:00, 279.25it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 348.10it/s]
# not saving the model
# not saving the model
# curr_lr: 0.001677721600000001
# curr_lr: 0.001677721600000001
# [43] Training loss: 0.245 Training accuracy : 0.896
# [43] Training loss: 0.245 Training accuracy : 0.896
# [43] Validation loss: 1.178 Validation accuracy : 0.592
# [43] Validation loss: 1.178 Validation accuracy : 0.592
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:02<00:00, 268.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 345.68it/s]
# not saving the model
# not saving the model
# curr_lr: 0.001677721600000001
# curr_lr: 0.001677721600000001
# [44] Training loss: 0.252 Training accuracy : 0.892
# [44] Training loss: 0.252 Training accuracy : 0.892
# [44] Validation loss: 1.191 Validation accuracy : 0.593
# [44] Validation loss: 1.191 Validation accuracy : 0.593
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:02<00:00, 263.03it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 329.92it/s]
# not saving the model
# not saving the model
# curr_lr: 0.001677721600000001
# curr_lr: 0.001677721600000001
# [45] Training loss: 0.249 Training accuracy : 0.895
# [45] Training loss: 0.249 Training accuracy : 0.895
# [45] Validation loss: 1.128 Validation accuracy : 0.593
# [45] Validation loss: 1.128 Validation accuracy : 0.593
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:02<00:00, 270.29it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 340.94it/s]
# not saving the model
# not saving the model
# curr_lr: 0.0013421772800000008
# curr_lr: 0.0013421772800000008
# [46] Training loss: 0.228 Training accuracy : 0.908
# [46] Training loss: 0.228 Training accuracy : 0.908
# [46] Validation loss: 1.116 Validation accuracy : 0.597
# [46] Validation loss: 1.116 Validation accuracy : 0.597
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:02<00:00, 254.12it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 331.18it/s]
# not saving the model
# not saving the model
# curr_lr: 0.0013421772800000008
# curr_lr: 0.0013421772800000008
# [47] Training loss: 0.231 Training accuracy : 0.906
# [47] Training loss: 0.231 Training accuracy : 0.906
# [47] Validation loss: 1.120 Validation accuracy : 0.597
# [47] Validation loss: 1.120 Validation accuracy : 0.597
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:02<00:00, 256.52it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 338.18it/s]
# not saving the model
# not saving the model
# curr_lr: 0.0013421772800000008
# curr_lr: 0.0013421772800000008
# [48] Training loss: 0.230 Training accuracy : 0.907
# [48] Training loss: 0.230 Training accuracy : 0.907
# [48] Validation loss: 1.106 Validation accuracy : 0.599
# [48] Validation loss: 1.106 Validation accuracy : 0.599
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:02<00:00, 253.92it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 340.66it/s]
# not saving the model
# not saving the model
# curr_lr: 0.0013421772800000008
# curr_lr: 0.0013421772800000008
# [49] Training loss: 0.234 Training accuracy : 0.905
# [49] Training loss: 0.234 Training accuracy : 0.905
# [49] Validation loss: 1.063 Validation accuracy : 0.601
# [49] Validation loss: 1.063 Validation accuracy : 0.601
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 553/553 [00:02<00:00, 259.50it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 339.45it/s]
# saving best model
# saving best model
# curr_lr: 0.0013421772800000008
# curr_lr: 0.0013421772800000008
# [50] Training loss: 0.237 Training accuracy : 0.903
# [50] Training loss: 0.237 Training accuracy : 0.903
# [50] Validation loss: 1.036 Validation accuracy : 0.605
# [50] Validation loss: 1.036 Validation accuracy : 0.605
# Finished Training

# %%
# # https://pytorch.org/tutorials/beginner/saving_loading_models.html
# for inference - load checkpointed model

PATH = checkpoint_path
checkpoint = torch.load(PATH)
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
loss = checkpoint['loss']
acc = checkpoint['accuracy']

# inferece
model.eval()
# Out:
# MemNetwork(
#   (linear): Sequential(
#     (0): Linear(in_features=400, out_features=400, bias=True)
#   )
# )

# %%
test_count = 0
output_logits_lstm = []
test_acc = 0
for context, query, labels in tqdm(test_loader):
    test_count += 1
    context = context.to(device)
    query = query.to(device)

    target = labels.to(device)
    label = labels.float().to(device)
        
    outputs = model(context, query)
    output_logits = outputs.detach().cpu().numpy()
    test_acc += torchmetrics.functional.accuracy(outputs, target, threshold=0.5).item()
    output_logits_lstm.append(output_logits)

accuracy = test_acc/test_count
print("The test accuracy is {}".format(accuracy))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 301/301 [00:00<00:00, 353.04it/s]
# The test accuracy is 0.6025111263376534

# %%
test_output_logits_lstm = np.hstack(output_logits_lstm)

# %%
lstm_pred = torch.sigmoid(torch.tensor(test_output_logits_lstm))
lstm_pred_label = 1.0 * (lstm_pred > 0.5)

# %%
torch.save(lstm_pred, 'lstm_pred.pt')
torch.save(lstm_pred_label, 'lstm_pred_label.pt')

# %%
lstm_pred
# Out:
# tensor([0.0835, 0.0686, 0.0205,  ..., 0.6746, 0.0989, 0.0123])

# %%
lstm_pred_label
# Out:
# tensor([0., 0., 0.,  ..., 1., 0., 0.])
